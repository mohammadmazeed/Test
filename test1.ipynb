# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadmazeed/Test/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
def check_even_odd(num,num2):
    if num%2==0:
        print("even")
    else:
        print("odd")

# %%
check_even_odd(2,1)
# Out:
# even

# %% [markdown]
# Question: Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.
#
# Hints: Consider use range(#begin, #end) method

# %%
from os.path import join
l=[]
for i in range(2000,3200):
  if (i%7==0) and (i%5!=0):
    l.append(i)
print(l)
# Out:
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199]

# %% [markdown]
# Question: Write a program which can compute the factorial of a given numbers. The results should be printed in a comma-separated sequence on a single line. Suppose the following input is supplied to the program: 8 Then, the output should be: 40320
#
# Hints: In case of input data being supplied to the question, it should be assumed to be a console input.

# %%
def fact(a):
  if a==0:
    return 1
  elif a<0:
    return "factorial cannot be defines for negative numbers."
  else:
    return a*fact(a-1)
a=int(input("enter the number to find the factorial of it ="))
print(fact(a))
# Out:
# enter the number to find the factorial of it =-1
# factorial cannot be defines for negative numbers.

# %%
a=int(input("enter the number to find the factorial of it ="))
factorail = 1
if a<0:
    print("factorial cannot be defines for negative numbers.")
elif a==0:
  print("factorial is",1)
else:
  for i in range(1,a+1):
    factorail *= i
  print("factoraial of given number is",factorail)
# Out:
# enter the number to find the factorial of it =5
# factoraial of given number is 120

# %% [markdown]
# Question: With a given integral number n, write a program to generate a dictionary that contains (i, i*i) such that is an integral number between 1 and n (both included). and then the program should print the dictionary. Suppose the following input is supplied to the program: 8 Then, the output should be: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}
#
# Hints: In case of input data being supplied to the question, it should be assumed to be a console input. Consider use dict()

# %%
n=int(input("enter the number"))
d=dict()
for i in range(1,n+1):
  d[i] = i*i
print(d)
# Out:
# enter the number5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### 1. Authenticate with GitHub
#
# To interact with GitHub from Colab, you'll need to authenticate. The most secure way is to use a [Personal Access Token (PAT)](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token).
#
# **Steps to create a PAT:**
# 1. Go to your GitHub settings.
# 2. Navigate to 'Developer settings' -> 'Personal access tokens' -> 'Tokens (classic)'.
# 3. Click 'Generate new token' and select 'Generate new token (classic)'.
# 4. Give it a descriptive name (e.g., 'Colab Access').
# 5. Set an expiration (e.g., 30 days or custom).
# 6. Select the necessary scopes. For cloning and pushing, you'll typically need at least `repo` scope.
# 7. Click 'Generate token' and **copy the token immediately** as you won't be able to see it again.
#
# Once you have your PAT, you can use it to clone repositories. You can store it securely in Colab's secrets manager (click the '🔑' icon on the left panel, add a new secret, and name it `GITHUB_TOKEN`).

# %% [markdown]
# ### 2. Configure Git and Clone your Repository
#
# First, you'll need to configure Git with your name and email. Then, you can clone your GitHub repository. Replace `YOUR_USERNAME`, `YOUR_REPOSITORY`, and `YOUR_GITHUB_TOKEN` with your actual details.
#
# If you stored your token in Colab secrets as `GITHUB_TOKEN`, you can access it like this:

# %%
# Optional: If you stored your token in Colab secrets
from google.colab import userdata

GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# Configure Git
# !git config --global user.email "your_email@example.com" # Replace with your email
# !git config --global user.name "Your Name" # Replace with your name

# Clone your repository using your PAT
# Replace 'YOUR_USERNAME' and 'YOUR_REPOSITORY' with your GitHub username and repository name
# Example: !git clone https://{GITHUB_TOKEN}@github.com/YOUR_USERNAME/YOUR_REPOSITORY.git

# For public repositories, you can clone without a token:
# !git clone https://github.com/YOUR_USERNAME/YOUR_REPOSITORY.git

# For private repositories or to push to public ones, use your token:
# IMPORTANT: Make sure to replace YOUR_USERNAME and YOUR_REPOSITORY
# !git clone https://{GITHUB_TOKEN}@github.com/YOUR_USERNAME/YOUR_REPOSITORY.git

# Navigate into your cloned repository
# %cd YOUR_REPOSITORY # Replace with your repository name
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3303/1412964208.py in <cell line: 0>()
#       2 from google.colab import userdata
#       3
# ----> 4 GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
#       5
#       6 # Configure Git
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GITHUB_TOKEN does not exist.

# %% [markdown]
# ### 3. Make Changes, Commit, and Push
#
# After cloning, you can make changes to files within that directory. For example, you might create new Python scripts or modify existing ones. Once you're ready to save these changes to GitHub:
#
# 1.  **Add** your changes to the staging area.
# 2.  **Commit** your changes with a message.
# 3.  **Push** your committed changes to the remote GitHub repository.

# %% [markdown]
# Question: Write a program which accepts a sequence of comma-separated numbers from console and generate a list and a tuple which contains every number. Suppose the following input is supplied to the program: 34,67,55,33,12,98 Then, the output should be: ['34', '67', '55', '33', '12', '98'] ('34', '67', '55', '33', '12', '98')
#
# Hints: In case of input data being supplied to the question, it should be assumed to be a console input. tuple() method can convert list to tuple

# %%
data=input("enter the comma separated values")
l=data.split("-")
fl=[int(i) for i in l]
t=tuple(fl)
print(fl)
print(t)
# Out:
# enter the comma separated values1-2-3
# [1, 2, 3]
# (1, 2, 3)

# %% [markdown]
# Question: Define a class which has at least two methods: getString: to get a string from console input printString: to print the string in upper case. Also please include simple test function to test the class methods.
#
# Hints: Use init method to construct some parameter

# %%
class InputOutString:
    def __init__(self):
        self.s = ""

    def getString(self):
        self.s = input()

    def printString(self):
        print(self.s.upper())

strObj = InputOutString()
strObj.getString()
strObj.printString()
# Out:
# gshhs
# GSHHS

# %% [markdown]
# Question: Write a program that calculates and prints the value according to the given formula: Q = Square root of [(2 * C * D)/H] Following are the fixed values of C and H: C is 50. H is 30. D is the variable whose values should be input to your program in a comma-separated sequence. Example Let us assume the following comma separated input sequence is given to the program: 100,150,180 The output of the program should be: 18,22,24
#
# Hints: If the output received is in decimal form, it should be rounded off to its nearest value (for example, if the output received is 26.0, it should be printed as 26) In case of input data being supplied to the question, it should be assumed to be a console input.

# %%
import math
c=50
h=30
value = []
items=[x for x in input().split(',')]
for d in items:
    value.append(str(int(round(math.sqrt(2*c*float(d)/h)))))

print(','.join(value))
# Out:
# 10,15,30
# 6,7,10

# %% [markdown]
# Question: Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional array. The element value in the i-th row and j-th column of the array should be i*j. Note: i=0,1.., X-1; j=0,1,¡­Y-1. Example Suppose the following inputs are given to the program: 3,5 Then, the output of the program should be: [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]
#
# Hints: Note: In case of input data being supplied to the question, it should be assumed to be a console input in a comma-separated form.

# %%
input_str = input()
dimensions=[int(x) for x in input_str.split(',')]
rowNum=dimensions[0]
colNum=dimensions[1]
multilist = [[0 for col in range(colNum)] for row in range(rowNum)]

for row in range(rowNum):
    for col in range(colNum):
      #print(row)
      #print(col)
        multilist[row][col]= row*col
        #print(multilist)
print(multilist)
# Out:
# 2,3
# [[0, 0, 0], [0, 1, 2]]

# %%
input_str=input(str())
print(input_str.upper())
# Out:
# ksdmlfsml
# KSDMLFSML

# %%
lines = []
while True:
    s = input()
    if s:
        lines.append(s.upper())
    else:
        break;

for sentence in lines:
    print(sentence)
# Out:
# hello world how are u
# are u good
#
# HELLO WORLD HOW ARE U
# ARE U GOOD
